# %%
import os
import time
import numpy as np
import pandas as pd
import mof_public

# %% [markdown]
# ## print raw html

# %%
mof_public.print_html("""<h2 style='color: red'>hello, there</h2>""")
# Out:
# <h2 style='color: red'>hello, there</h2>

# %% [markdown]
# ## print colorful text

# %%
mof_public.print_text(text='Things happen for a reason --- from /Knight and Day/', color='blue')
# Out:
# <h1 style='color: blue;text-align: center'>Things happen for a reason --- from /Knight and Day/</h1>

# %% [markdown]
# ## plot progress bar

# %%
mof_public.print_progressbar(0, initial_bar=True)
for i in range(1, 101):
    mof_public.print_progressbar(i, initial_bar=False)
    time.sleep(np.random.rand() / 3)
# Out:
#          <div id="myProgress">
#            <div id="myBar" class='barbar'></div>
#          </div>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 1 + '%';
#                 elem.innerHTML = 1;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 2 + '%';
#                 elem.innerHTML = 2;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 3 + '%';
#                 elem.innerHTML = 3;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 4 + '%';
#                 elem.innerHTML = 4;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 5 + '%';
#                 elem.innerHTML = 5;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 6 + '%';
#                 elem.innerHTML = 6;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 7 + '%';
#                 elem.innerHTML = 7;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 8 + '%';
#                 elem.innerHTML = 8;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 9 + '%';
#                 elem.innerHTML = 9;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 10 + '%';
#                 elem.innerHTML = 10;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 11 + '%';
#                 elem.innerHTML = 11;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 12 + '%';
#                 elem.innerHTML = 12;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 13 + '%';
#                 elem.innerHTML = 13;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 14 + '%';
#                 elem.innerHTML = 14;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 15 + '%';
#                 elem.innerHTML = 15;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 16 + '%';
#                 elem.innerHTML = 16;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 17 + '%';
#                 elem.innerHTML = 17;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 18 + '%';
#                 elem.innerHTML = 18;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 19 + '%';
#                 elem.innerHTML = 19;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 20 + '%';
#                 elem.innerHTML = 20;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 21 + '%';
#                 elem.innerHTML = 21;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 22 + '%';
#                 elem.innerHTML = 22;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 23 + '%';
#                 elem.innerHTML = 23;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 24 + '%';
#                 elem.innerHTML = 24;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 25 + '%';
#                 elem.innerHTML = 25;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 26 + '%';
#                 elem.innerHTML = 26;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 27 + '%';
#                 elem.innerHTML = 27;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 28 + '%';
#                 elem.innerHTML = 28;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 29 + '%';
#                 elem.innerHTML = 29;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 30 + '%';
#                 elem.innerHTML = 30;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 31 + '%';
#                 elem.innerHTML = 31;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 32 + '%';
#                 elem.innerHTML = 32;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 33 + '%';
#                 elem.innerHTML = 33;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 34 + '%';
#                 elem.innerHTML = 34;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 35 + '%';
#                 elem.innerHTML = 35;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 36 + '%';
#                 elem.innerHTML = 36;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 37 + '%';
#                 elem.innerHTML = 37;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 38 + '%';
#                 elem.innerHTML = 38;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 39 + '%';
#                 elem.innerHTML = 39;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 40 + '%';
#                 elem.innerHTML = 40;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 41 + '%';
#                 elem.innerHTML = 41;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 42 + '%';
#                 elem.innerHTML = 42;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 43 + '%';
#                 elem.innerHTML = 43;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 44 + '%';
#                 elem.innerHTML = 44;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 45 + '%';
#                 elem.innerHTML = 45;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 46 + '%';
#                 elem.innerHTML = 46;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 47 + '%';
#                 elem.innerHTML = 47;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 48 + '%';
#                 elem.innerHTML = 48;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 49 + '%';
#                 elem.innerHTML = 49;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 50 + '%';
#                 elem.innerHTML = 50;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 51 + '%';
#                 elem.innerHTML = 51;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 52 + '%';
#                 elem.innerHTML = 52;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 53 + '%';
#                 elem.innerHTML = 53;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 54 + '%';
#                 elem.innerHTML = 54;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 55 + '%';
#                 elem.innerHTML = 55;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 56 + '%';
#                 elem.innerHTML = 56;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 57 + '%';
#                 elem.innerHTML = 57;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 58 + '%';
#                 elem.innerHTML = 58;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 59 + '%';
#                 elem.innerHTML = 59;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 60 + '%';
#                 elem.innerHTML = 60;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 61 + '%';
#                 elem.innerHTML = 61;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 62 + '%';
#                 elem.innerHTML = 62;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 63 + '%';
#                 elem.innerHTML = 63;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 64 + '%';
#                 elem.innerHTML = 64;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 65 + '%';
#                 elem.innerHTML = 65;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 66 + '%';
#                 elem.innerHTML = 66;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 67 + '%';
#                 elem.innerHTML = 67;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 68 + '%';
#                 elem.innerHTML = 68;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 69 + '%';
#                 elem.innerHTML = 69;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 70 + '%';
#                 elem.innerHTML = 70;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 71 + '%';
#                 elem.innerHTML = 71;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 72 + '%';
#                 elem.innerHTML = 72;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 73 + '%';
#                 elem.innerHTML = 73;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 74 + '%';
#                 elem.innerHTML = 74;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 75 + '%';
#                 elem.innerHTML = 75;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 76 + '%';
#                 elem.innerHTML = 76;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 77 + '%';
#                 elem.innerHTML = 77;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 78 + '%';
#                 elem.innerHTML = 78;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 79 + '%';
#                 elem.innerHTML = 79;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 80 + '%';
#                 elem.innerHTML = 80;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 81 + '%';
#                 elem.innerHTML = 81;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 82 + '%';
#                 elem.innerHTML = 82;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 83 + '%';
#                 elem.innerHTML = 83;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 84 + '%';
#                 elem.innerHTML = 84;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 85 + '%';
#                 elem.innerHTML = 85;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 86 + '%';
#                 elem.innerHTML = 86;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 87 + '%';
#                 elem.innerHTML = 87;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 88 + '%';
#                 elem.innerHTML = 88;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 89 + '%';
#                 elem.innerHTML = 89;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 90 + '%';
#                 elem.innerHTML = 90;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 91 + '%';
#                 elem.innerHTML = 91;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 92 + '%';
#                 elem.innerHTML = 92;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 93 + '%';
#                 elem.innerHTML = 93;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 94 + '%';
#                 elem.innerHTML = 94;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 95 + '%';
#                 elem.innerHTML = 95;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 96 + '%';
#                 elem.innerHTML = 96;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 97 + '%';
#                 elem.innerHTML = 97;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 98 + '%';
#                 elem.innerHTML = 98;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 99 + '%';
#                 elem.innerHTML = 99;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>
#                 <script id="fuck">
#
#                 var elem = document.getElementById("myBar");
#                 elem.style.width = 100 + '%';
#                 elem.innerHTML = 100;
#
#                 document.getElementById('fuck').parentElement.parentElement.remove();
#
#                 </script>

# %% [markdown]
# ## plot dataframe in excel format

# %%
from lib import daily_report

### 
file_path = "/Ussers/chenshan/google_driver/github/litaotao.github.io/files"
try: 
    os.listdir(file_path)
except:
    file_path = "http://litaotao.github.io/files/"
    
print 'use data file path: ', file_path
# Out:
# use data file path:  http://litaotao.github.io/files/

# %%
df1 = pd.read_msgpack('{}/dazong1.msg'.format(file_path))
df2 = pd.read_msgpack('{}/dazong2.msg'.format(file_path))

print 'raw print dataframe'
print df1.head(2)
print df2.head(2)

print '\nprint dataframe with mof_public'
mof_public.print_table(df1.head(2))
mof_public.print_table(df2.head(2))
# Out:
# raw print dataframe
#     tradeDate      tradeVal
# 0  2016-09-20  3.085667e+09
# 1  2016-09-21  3.659584e+09
#   secFullName   tradeVal
# 0         新华锦  2212000.0
# 1         木林森  2276000.0
#
# print dataframe with mof_public
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tradeDate</th>
#       <th>tradeVal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-09-20</td>
#       <td>3.085667e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2016-09-21</td>
#       <td>3.659584e+09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>secFullName</th>
#       <th>tradeVal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>新华锦</td>
#       <td>2212000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>木林森</td>
#       <td>2276000.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## plot bar/line charts

# %%
mof_public.draw?

# %%
### notebook 环境下，如果把 mof_public.draw 运行结果显示的返回给一个变量，则 notebook 不会自动画图
figure = mof_public.draw(df1, x='tradeDate', y=['tradeVal'], type='spline', stock=True,title='大宗交易成交金额')

# %%
### notebook 环境下，如果   没有   把 mof_public.draw 运行结果显示的返回给一个变量，则 notebook 会自动画图
mof_public.draw(df1, x='tradeDate', y=['tradeVal'], type='spline', stock=True,title='大宗交易成交金额')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor

# %%
mof_public.draw(df2, x='secFullName', y=['tradeVal'], type='column', title='{} 个股大宗交易成交金额'.format('2017-09-26'), x_type='str')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor

# %% [markdown]
# ## plot multi-bar

# %%
df3 = pd.read_msgpack('{}/money_flow1.msg'.format(file_path))
df3.tail(2)
# Out:
#      tradeDate     industryID       inflowS       inflowM       inflowL  \
# 18  2017-09-25  2346944859657  3.187079e+11  7.244537e+10  1.213898e+10
# 19  2017-09-26  2346944859657  2.935276e+11  6.591013e+10  1.143167e+10
#
#         inflowXl      outflowS      outflowM      outflowL     outflowXl  \
# 18  8.605108e+09 -3.995206e+11 -9.870362e+10 -1.496879e+10 -6.620669e+09
# 19  1.184931e+10 -3.338497e+11 -6.887607e+10 -8.230659e+09 -4.407431e+09
#
#            小单净流入         中单净流入         大单净流入   netInflowXl
# 18 -8.081273e+10 -2.625826e+10 -8.453664e+08  1.984439e+09
# 19 -4.032207e+10 -2.965939e+09  1.064290e+10  7.441883e+09

# %%
mof_public.draw(df3, x='tradeDate', y=['小单净流入', '中单净流入', '大单净流入'], type='column', title='市场成单资金分布', x_type='str')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor

# %% [markdown]
# ## plot multi-line
#
# - `stock=True`: will use highstock.js to make the drawing
# - `stock=False`: will use highcharts.js to make the drawing

# %%
df4 = pd.read_msgpack('{}/risk_factor1.msg'.format(file_path))
df4.tail(2)
# Out:
#     tradeDate      BETA  MOMENTUM      SIZE  EARNYILD    RESVOL    GROWTH  \
# 1  2017-09-25  1.166488  0.959253  0.588976  1.515041  0.876979  1.281543
# 0  2017-09-26  1.166916  0.956959  0.590286  1.517409  0.881353  1.280521
#
#        BTOP  LEVERAGE  LIQUIDTY    SIZENL      Bank  RealEstate    Health  \
# 1  1.281047  0.938985  0.800227 -0.003665  0.004260   -0.042494  0.009833
# 0  1.279931  0.940823  0.799971  0.004207 -0.004919   -0.000191 -0.001646
#
#    Transportation    Mining  NonFerMetal  HouseApp  LeiService  MachiEquip  \
# 1       -0.000308  0.003575    -0.010106 -0.008646    0.001895   -0.002539
# 0       -0.000822  0.007808     0.004957 -0.013897    0.019601   -0.000503
#
#    BuildDeco  CommeTrade    CONMAT      Auto   Textile  FoodBever  \
# 1  -0.002204   -0.003496  0.008195  0.001672 -0.000651   0.018976
# 0  -0.002615   -0.004241 -0.006000  0.002393 -0.002425   0.002648
#
#    Electronics  Computer  LightIndus  Utilities   Telecom  AgriForest  \
# 1    -0.007857  0.008398   -0.006948  -0.003017 -0.009844   -0.003812
# 0     0.010677 -0.009473   -0.000364  -0.000677  0.005501   -0.001684
#
#        CHEM     Media  IronSteel  NonBankFinan   ELECEQP   AERODEF  \
# 1  0.003164 -0.000238   0.003216      0.007960  0.000350  0.007128
# 0  0.007017 -0.002226   0.009727     -0.001817 -0.004836  0.005309
#
#    Conglomerates   COUNTRY           updateTime
# 1      -0.014175 -0.006980  2017-09-25 17:47:53
# 0       0.000566  0.001346  2017-09-26 17:59:35

# %%
mof.draw(df4, x='tradeDate', type='spline', title='大类风格因子表现',
         y=['MOMENTUM', 'BETA', 'SIZE', 'EARNYILD', 'LIQUIDTY', 'RESVOL', 'GROWTH', 'BTOP', 'LEVERAGE'])
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor

# %%
mof.draw(df4, x='tradeDate', type='spline', title='大类风格因子表现', stock=True,
         y=['MOMENTUM', 'BETA', 'SIZE', 'EARNYILD', 'LIQUIDTY', 'RESVOL', 'GROWTH', 'BTOP', 'LEVERAGE'])
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor

# %% [markdown]
# ## plot 2 plots in one raw

# %%
figure1 = mof.draw(df4, x='tradeDate', type='spline', title='大类风格因子表现', stock=False,
                   y=['MOMENTUM', 'BETA', 'SIZE', 'EARNYILD', 'LIQUIDTY', 'RESVOL', 'GROWTH', 'BTOP', 'LEVERAGE'])
figure2 = mof_public.draw(df3, x='tradeDate', y=['小单净流入', '中单净流入', '大单净流入'], type='column', title='市场成单资金分布', x_type='str')

# %%
mof_public.draw_figure?

# %%
mof_public.draw_figure(figure1, figure2)
# Out:
# <div>
#  <div style="width:50%; height:400px; float:left; text-align:-webkit-center; overflow: scroll"><style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10" style="display: none;">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2" style="display: none;">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highc
